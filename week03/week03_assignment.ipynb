# %% [markdown]
# # 3주차 과제
# 빅데이터프로그래밍 · 통계학과
#
# **이름:**
# **학번:**
#
# ## 과제 내용
# 공개 CSV 데이터를 하나 선택해 아래 항목을 정리합니다.
#
# 1. 데이터 구조 (행·열·자료형)
# 2. 결측값 현황
# 3. 자료형 문제와 처리 방법
# 4. 전처리 전후 비교표
# 5. Tensor 변환 결과
#
# ## 제출 방법
# 모든 셀을 실행해 출력이 보이는 상태로 저장한 뒤 `week03_학번_이름.ipynb` 로 제출합니다.
#
# ## 데이터 선택
# 아래 중 하나를 쓰거나, 직접 찾은 공개 CSV를 써도 됩니다.
#
# - seaborn 내장 데이터: `titanic`, `penguins`, `tips`
# - 직접 만든 CSV

# %%
import pandas as pd
import numpy as np
import torch

# 예시: seaborn 내장 데이터 (인터넷 연결 필요)
import seaborn as sns
df = sns.load_dataset("penguins")
df.head()

# %% [markdown]
# ## 문제 1. 데이터 구조 확인 (20점)
# `shape`, `columns`, `dtypes`, `head()`, `info()` 를 출력하고 무엇을 알 수 있었는지 한 줄로 적으세요.

# %%
# 답안

# %% [markdown]
# ## 문제 2. 결측값 처리 (25점)
# 열별 결측 개수를 출력하고, 각 열을 **삭제 또는 대체** 중 무엇으로 처리했는지 이유와 함께 적으세요.

# %%
# 답안

# %% [markdown]
# ## 문제 3. 자료형 처리 (25점)
# 문자형 열을 숫자로 바꾸세요. 값이 두 개면 0/1, 셋 이상이면 원-핫 인코딩을 씁니다.

# %%
# 답안

# %% [markdown]
# ## 문제 4. 전처리 전후 비교표 (20점)
# 아래 형태의 표를 만들어 출력하세요.
#
# | 항목 | 전처리 전 | 전처리 후 |
# | --- | --- | --- |
# | 행 개수 | | |
# | 열 개수 | | |
# | 결측 개수 | | |
# | object 열 개수 | | |

# %%
# 답안 — pd.DataFrame 으로 만들어 출력하세요

# %% [markdown]
# ## 문제 5. Tensor 변환 (10점)
# 전처리한 입력을 `float32` Tensor로 바꾸고, 개수 · shape · dtype · 최솟값 · 최댓값 · NaN 개수를 출력하세요.

# %%
# 답안
