# %% [markdown]
# # 1주차 과제
# 빅데이터프로그래밍 · 통계학과
#
# **이름:**
# **학번:**
#
# ## 제출 방법
# 1. 이 노트북의 모든 셀을 실행해 **출력 결과가 보이는 상태**로 저장합니다.
# 2. `파일 > 다운로드 > .ipynb 다운로드` 로 내려받아 제출합니다.
# 3. 파일명: `week01_학번_이름.ipynb`

# %% [markdown]
# ## 문제 1. 숫자 5개의 평균과 최댓값 (20점)
# 리스트에 숫자 5개를 담고, 평균과 최댓값을 출력하세요. 평균은 소수점 둘째 자리까지.

# %%
# 답안

# %% [markdown]
# ## 문제 2. 하루 지출 계산 프로그램 (40점)
# 항목 이름과 금액을 딕셔너리에 저장하고 아래를 출력하세요.
# - 총 지출액
# - 가장 많이 쓴 항목과 금액
# - 항목별 지출이 총액에서 차지하는 비율(%)

# %%
expenses = {
    "점심": 9000,
    "커피": 4500,
    "교통": 2800,
    "간식": 3200,
}

# 답안

# %% [markdown]
# ## 문제 3. 오류 고치기 (20점)
# 아래 셀에는 오류가 있습니다. 실행해 메시지를 읽고 고친 뒤, **어떤 오류였는지** 주석으로 적으세요.

# %%
data = [3, 7, 11]
result = 0
for i in range(4):
    result += data[i]
print("합계: " + result)

# %% [markdown]
# ## 문제 4. Tensor 만들기 (20점)
# 1. `torch.arange` 로 0부터 11까지의 텐서를 만드세요.
# 2. 그것을 (3, 4) 모양으로 바꾸세요.
# 3. shape, dtype, 전체 평균을 출력하세요.

# %%
import torch

# 답안
