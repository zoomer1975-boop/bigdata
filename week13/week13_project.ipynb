# %% [markdown]
# # 13주차 프로젝트
# 빅데이터프로그래밍 · 통계학과
#
# **이름:**
# **학번:**
# **프로젝트 제목:**
#
# ---
#
# ## 제출물 세 가지
#
# 1. **실행 가능한 Notebook** — 이 파일 (`week13_학번_이름.ipynb`)
# 2. **발표용 PowerPoint** — 6장 구성 (아래 안내 참고)
# 3. **결과 요약문** — A4 한 장
#
# ## 채점 기준
#
# | 항목 | 배점 |
# | --- | --- |
# | 계획서 (문제·데이터·모델·성공 기준) | 15 |
# | 데이터 확인과 전처리 | 15 |
# | 모델 구성과 설명 | 20 |
# | 학습과 평가 (그래프 포함) | 20 |
# | 오류 분석 | 20 |
# | 발표 자료와 요약문 | 10 |
#
# ## 주제 예시
# 아래에서 골라도 되고 직접 정해도 됩니다.
#
# - 의류 이미지 분류 (Fashion-MNIST) — 8·9주차 연장
# - 꽃 이미지 분류 (전이학습) — 10주차 연장
# - 문장 감성 분석 (IMDB) — 12주차 연장
# - 시계열 예측 (사인파·기온·전력) — 11주차 연장
# - 손글씨 숫자 분류 (MNIST) — 7주차 연장

# %% [markdown]
# ---
# # 계획서 (15점)
#
# ## 1. 해결할 문제
#
# **한 문장으로:**
#
# >
#
# **왜 이 문제인가:**
#
# >
#
# ## 2. 사용할 데이터
#
# | 항목 | 내용 |
# | --- | --- |
# | 데이터 이름 | |
# | 출처 | |
# | 학습 / 검증 개수 | |
# | 클래스 수 또는 예측 대상 | |
#
# ## 3. 입력과 출력
#
# | | shape | 설명 |
# | --- | --- | --- |
# | 입력 | | |
# | 출력 | | |
# | 정답 | | |
#
# ## 4. 사용할 모델
#
# | 항목 | 내용 |
# | --- | --- |
# | 모델 종류 | |
# | 왜 이 모델인가 | |
# | 손실 함수 | |
# | 최적화 · 학습률 | |
#
# ## 5. 성공 기준
#
# | 기준 | 목표값 |
# | --- | --- |
# | 최소 기준 | |
# | 목표 | |
# | 비교 대상 | |

# %%
# ===== 공통 준비 =====
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

SEED = 42
torch.manual_seed(SEED); np.random.seed(SEED)
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)

# %% [markdown]
# ---
# # 1. 데이터 확인 (15점 중 일부)
#
# 아래를 모두 출력하세요.
# - 학습 / 검증 데이터 개수
# - 입력 하나의 shape과 값 범위
# - 정답의 형태
# - 클래스 분포 (분류라면) 또는 값 분포 (회귀라면)
# - 표본 8개 이상을 눈으로 확인

# %%
# 답안

# %% [markdown]
# ---
# # 2. 전처리 (15점 중 일부)
#
# 무엇을 왜 했는지 주석으로 적으세요. 증강은 학습 데이터에만 적용합니다.

# %%
# 답안

# %% [markdown]
# ---
# # 3. Dataset과 DataLoader
#
# batch 하나의 shape을 출력해 확인하세요.

# %%
# 답안

# %% [markdown]
# ---
# # 4. 모델 (20점)
#
# - 모델을 작성하고 `print(model)` 로 구조를 출력하세요
# - 더미 입력으로 출력 shape을 확인하세요
# - 파라미터 수를 출력하세요
# - **왜 이 구조인지** 주석 또는 markdown으로 설명하세요

# %%
# 답안

# %% [markdown]
# **모델 설명:**
#
# >

# %% [markdown]
# ---
# # 5. 학습 (20점 중 일부)
#
# epoch마다 학습·검증 손실과 정확도(또는 오차)를 기록하세요. 학습 시간도 재세요.

# %%
# 답안

# %% [markdown]
# ---
# # 6. 평가 (20점 중 일부)
#
# - 최종 / 최고 성능
# - 학습-검증 차이
# - 성공 기준 달성 여부
# - 클래스별 정확도 (분류) 또는 구간별 오차 (회귀)

# %%
# 답안

# %% [markdown]
# ---
# # 7. 시각화
#
# - 손실 곡선 (학습·검증)
# - 정확도 곡선 (학습·검증) 또는 실제 vs 예측 그래프
# - 예측 결과 표본
# - 혼동행렬 (분류)

# %%
# 답안

# %% [markdown]
# ---
# # 8. 오류 분석 (20점)
#
# 아래를 모두 하세요.
#
# 1. 틀린 사례를 8개 이상 그리고, 예측·정답·확률을 함께 표시
# 2. 확신하고 틀린 것과 애매해서 틀린 것을 구분
# 3. 가장 많이 헷갈린 쌍 3개
# 4. 각 오류의 원인을 **숫자 근거와 함께** 추정

# %%
# 답안

# %% [markdown]
# **오류 분석:**
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ---
# # 9. 모델의 한계와 개선 방향
#
# | 한계 | 숫자 근거 | 개선 방향 |
# | --- | --- | --- |
# | | | |
# | | | |
# | | | |
#
# 한계마다 반드시 숫자 근거를 적으세요.

# %% [markdown]
# ---
# # 10. 결과 요약 — 발표 자료에 옮길 내용

# %%
# 아래 표를 자기 프로젝트 값으로 채워 출력하세요
summary = pd.DataFrame([
    {"항목": "문제",            "내용": ""},
    {"항목": "데이터",          "내용": ""},
    {"항목": "모델",            "내용": ""},
    {"항목": "파라미터",        "내용": ""},
    {"항목": "학습 조건",       "내용": ""},
    {"항목": "최종 성능",       "내용": ""},
    {"항목": "성공 기준 달성",   "내용": ""},
    {"항목": "학습 시간",       "내용": ""},
    {"항목": "주요 한계",       "내용": ""},
])
print(summary.to_string(index=False))

# %% [markdown]
# ---
# # 발표 자료 6장 구성 (10점)
#
# PowerPoint를 아래 순서로 만드세요. 한 장에 한 가지만 담습니다.
#
# | 장 | 내용 | 넣을 것 |
# | --- | --- | --- |
# | 1 | 문제 정의 | 한 문장 문제 + 왜 이 문제인가 |
# | 2 | 데이터 | 개수 · shape · 표본 이미지 몇 개 |
# | 3 | 모델 | 구조 그림 또는 층 목록 + 파라미터 수 |
# | 4 | 학습 결과 | 손실·정확도 곡선 + 최종 성능 숫자 |
# | 5 | 오류 사례 | 틀린 사례 이미지 + 혼동행렬 |
# | 6 | 결론 | 성공 기준 달성 여부 · 한계 · 개선 방향 |
#
# ## 결과 요약문 (A4 한 장)
#
# 아래 순서로 씁니다.
#
# 1. 무엇을 했는가 (2~3줄)
# 2. 데이터와 모델 (3~4줄)
# 3. 결과 — 숫자를 반드시 포함 (3~4줄)
# 4. 무엇이 잘 안 됐는가 (3~4줄)
# 5. 다음에 무엇을 하겠는가 (2~3줄)

# %% [markdown]
# ---
# # 최종 제출 체크리스트
#
# - [ ] 런타임을 초기화하고 처음부터 끝까지 실행했다
# - [ ] 데이터와 레이블을 설명했다
# - [ ] 모델 구조를 설명했다
# - [ ] 학습 결과를 그래프로 제시했다
# - [ ] 틀린 예측을 분석했다
# - [ ] 성공 기준과 결과를 비교했다
# - [ ] 한계마다 숫자 근거를 적었다
# - [ ] 발표 자료 6장을 만들었다
# - [ ] 결과 요약문 A4 한 장을 썼다
